# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m

onsite= 1
hopping= 3
energy_range = np.linspace(o-2*hopping, o+2*hopping , 200000)


def density_of_states(energy):
    x= np.pi *(np.sqrt((4 * onsite**2) - (energy-onsite)**2))
    return 1/x
    


dos = [density_of_states(energy) for energy in energy_range]

plt.plot(energy_range, dos)
plt.title('Density of States vs Energy')
plt.xlabel('Energy')
plt.ylabel('Density of States')

plt.show
# Out:
# /private/var/mobile/Containers/Data/Application/4D6616F5-510E-4E0E-ABA0-D835A56259BA/tmp/ipykernel_9066/2080354020.py:11: RuntimeWarning: invalid value encountered in sqrt
#   x= np.pi *(np.sqrt((4 * onsite**2) - (energy-onsite)**2))
# <function matplotlib.pyplot.show(close=None, block=None)>
